# %%
import sys, random, os, json
sys.path.append(os.path.join(os.getcwd(), '..'))
from datamart.augment import Augment
from datamart.utilities.utils import Utils
import pandas as pd

# %%
es_index = "datamart_all"

augment = Augment(es_index=es_index)

# %% [markdown]
# ### Querying Gold, FTSE 100 United Kingdom, GDP Annual Growth

# %% [markdown]
# ### Quering for Gold Dataset

# %%
hitted_metadatas = augment.query(
    query_string="Gold AND tradingeconomics.com"
)

print(len(hitted_metadatas))
# Out:
# GET http://dsbox02.isi.edu:9200/datamart_all/_search?size=5000&from=0 [status:N/A request:10.033s]
# Traceback (most recent call last):
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connection.py", line 171, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/util/connection.py", line 79, in create_connection
#     raise err
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/util/connection.py", line 69, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/elasticsearch/connection/http_urllib3.py", line 172, in perform_request
#     response = self.pool.urlopen(method, url, body, retries=Retry(False), headers=request_headers, **kw)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/util/retry.py", line 343, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/packages/six.py", line 686, in reraise
#     raise value
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connectionpool.py", line 354, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/http/client.py", line 1239, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/http/client.py", line 1285, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/http/client.py", line 1234, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/http/client.py", line 1026, in _send_output
#     self.send(msg)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/http/client.py", line 964, in send
#     self.connect()
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connection.py", line 196, in connect
#     conn = self._new_conn()
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connection.py", line 176, in _new_conn
#     (self.host, self.timeout))
# urllib3.exceptions.ConnectTimeoutError: (<urllib3.connection.HTTPConnection object at 0x1195ed898>, 'Connection to dsbox02.isi.edu timed out. (connect timeout=10)')
# GET http://dsbox02.isi.edu:9200/datamart_all/_search?size=5000&from=0 [status:N/A request:10.002s]
# Traceback (most recent call last):
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connection.py", line 171, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/util/connection.py", line 79, in create_connection
#     raise err
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/util/connection.py", line 69, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/elasticsearch/connection/http_urllib3.py", line 172, in perform_request
#     response = self.pool.urlopen(method, url, body, retries=Retry(False), headers=request_headers, **kw)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/util/retry.py", line 343, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/packages/six.py", line 686, in reraise
#     raise value
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connectionpool.py", line 354, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/http/client.py", line 1239, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/http/client.py", line 1285, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/http/client.py", line 1234, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/http/client.py", line 1026, in _send_output
#     self.send(msg)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/http/client.py", line 964, in send
#     self.connect()
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connection.py", line 196, in connect
#     conn = self._new_conn()
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connection.py", line 176, in _new_conn
#     (self.host, self.timeout))
# urllib3.exceptions.ConnectTimeoutError: (<urllib3.connection.HTTPConnection object at 0x11acb7668>, 'Connection to dsbox02.isi.edu timed out. (connect timeout=10)')
# GET http://dsbox02.isi.edu:9200/datamart_all/_search?size=5000&from=0 [status:N/A request:10.002s]
# Traceback (most recent call last):
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connection.py", line 171, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/util/connection.py", line 79, in create_connection
#     raise err
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/util/connection.py", line 69, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/elasticsearch/connection/http_urllib3.py", line 172, in perform_request
#     response = self.pool.urlopen(method, url, body, retries=Retry(False), headers=request_headers, **kw)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/util/retry.py", line 343, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/packages/six.py", line 686, in reraise
#     raise value
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connectionpool.py", line 354, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/http/client.py", line 1239, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/http/client.py", line 1285, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/http/client.py", line 1234, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/http/client.py", line 1026, in _send_output
#     self.send(msg)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/http/client.py", line 964, in send
#     self.connect()
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connection.py", line 196, in connect
#     conn = self._new_conn()
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connection.py", line 176, in _new_conn
#     (self.host, self.timeout))
# urllib3.exceptions.ConnectTimeoutError: (<urllib3.connection.HTTPConnection object at 0x11a1cd470>, 'Connection to dsbox02.isi.edu timed out. (connect timeout=10)')
# GET http://dsbox02.isi.edu:9200/datamart_all/_search?size=5000&from=0 [status:N/A request:10.003s]
# Traceback (most recent call last):
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connection.py", line 171, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/util/connection.py", line 79, in create_connection
#     raise err
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/util/connection.py", line 69, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/elasticsearch/connection/http_urllib3.py", line 172, in perform_request
#     response = self.pool.urlopen(method, url, body, retries=Retry(False), headers=request_headers, **kw)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/util/retry.py", line 343, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/packages/six.py", line 686, in reraise
#     raise value
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connectionpool.py", line 354, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/http/client.py", line 1239, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/http/client.py", line 1285, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/http/client.py", line 1234, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/http/client.py", line 1026, in _send_output
#     self.send(msg)
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/http/client.py", line 964, in send
#     self.connect()
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connection.py", line 196, in connect
#     conn = self._new_conn()
#   File "/Users/sukriti/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connection.py", line 176, in _new_conn
#     (self.host, self.timeout))
# urllib3.exceptions.ConnectTimeoutError: (<urllib3.connection.HTTPConnection object at 0x11a1df780>, 'Connection to dsbox02.isi.edu timed out. (connect timeout=10)')
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     170             conn = connection.create_connection(
# --> 171                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     172
#
# ~/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      78     if err is not None:
# ---> 79         raise err
#      80
#
# ~/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      68                 sock.bind(source_address)
# ---> 69             sock.connect(sa)
#      70             return sock
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# ~/anaconda3/envs/datamart_env/lib/python3.6/site-packages/elasticsearch/connection/http_urllib3.py in perform_request(self, method, url, params, body, timeout, ignore, headers)
#     171
# --> 172             response = self.pool.urlopen(method, url, body, retries=Retry(False), headers=request_headers, **kw)
#     173             duration = time.time() - start
#
# ~/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     342             # Disabled, indicate to re-raise the error.
# --> 343             raise six.reraise(type(error), error, _stacktrace)
#     344
#
# ~/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     685             raise value.with_traceback(tb)
# --> 686         raise value
#     687
#
# ~/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# ~/anaconda3/envs/datamart_env/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# ~/anaconda3/envs/datamart_env/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# ~/anaconda3/envs/datamart_env/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# ~/anaconda3/envs/datamart_env/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# ~/anaconda3/envs/datamart_env/lib/python3.6/http/client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# ~/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     195     def connect(self):
# --> 196         conn = self._new_conn()
#     197         self._prepare_conn(conn)
#
# ~/anaconda3/envs/datamart_env/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     175                 self, "Connection to %s timed out. (connect timeout=%s)" %
# --> 176                 (self.host, self.timeout))
#     177
#
# ConnectTimeoutError: (<urllib3.connection.HTTPConnection object at 0x11a1df780>, 'Connection to dsbox02.isi.edu timed out. (connect timeout=10)')
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-86-7665e2b5611d> in <module>
#       1 hitted_metadatas = augment.query(
# ----> 2     query_string="Gold AND tradingeconomics.com"
#       3 )
#       4
#       5 print(len(hitted_metadatas))
#
# ~/PycharmProjects/datamart/example/../datamart/augment.py in query(self, col, minimum_should_match_ratio_for_col, query_string, temporal_coverage_start, temporal_coverage_end, global_datamart_id, variable_datamart_id, key_value_pairs, **kwargs)
#      91             return self._query_all()
#      92
# ---> 93         return self.qm.search(body=self.qm.form_conjunction_query(queries), **kwargs)
#      94
#      95     def _query_by_es_query(self, body: str, **kwargs) -> typing.Optional[typing.List[dict]]:
#
# ~/PycharmProjects/datamart/example/../datamart/es_managers/query_manager.py in search(self, body, size, from_index, **kwargs)
#      38         """
#      39
# ---> 40         result = self.es.search(index=self.es_index, body=body, size=size, from_=from_index, **kwargs)
#      41         count = result["hits"]["total"]
#      42         if count <= 0:
#
# ~/anaconda3/envs/datamart_env/lib/python3.6/site-packages/elasticsearch/client/utils.py in _wrapped(*args, **kwargs)
#      74                 if p in kwargs:
#      75                     params[p] = kwargs.pop(p)
# ---> 76             return func(*args, params=params, **kwargs)
#      77         return _wrapped
#      78     return _wrapper
#
# ~/anaconda3/envs/datamart_env/lib/python3.6/site-packages/elasticsearch/client/__init__.py in search(self, index, doc_type, body, params)
#     658             index = '_all'
#     659         return self.transport.perform_request('GET', _make_path(index,
# --> 660             doc_type, '_search'), params=params, body=body)
#     661
#     662     @query_params('_source', '_source_exclude', '_source_include',
#
# ~/anaconda3/envs/datamart_env/lib/python3.6/site-packages/elasticsearch/transport.py in perform_request(self, method, url, headers, params, body)
#     316                 delay = 2**attempt - 1
#     317                 time.sleep(delay)
# --> 318                 status, headers_response, data = connection.perform_request(method, url, params, body, headers=headers, ignore=ignore, timeout=timeout)
#     319
#     320             except TransportError as e:
#
# ~/anaconda3/envs/datamart_env/lib/python3.6/site-packages/elasticsearch/connection/http_urllib3.py in perform_request(self, method, url, params, body, timeout, ignore, headers)
#     179             if isinstance(e, ReadTimeoutError):
#     180                 raise ConnectionTimeout('TIMEOUT', str(e), e)
# --> 181             raise ConnectionError('N/A', str(e), e)
#     182
#     183         # raise errors based on http status codes, let the client handle those if needed
#
# ConnectionError: ConnectionError((<urllib3.connection.HTTPConnection object at 0x11a1df780>, 'Connection to dsbox02.isi.edu timed out. (connect timeout=10)')) caused by: ConnectTimeoutError((<urllib3.connection.HTTPConnection object at 0x11a1df780>, 'Connection to dsbox02.isi.edu timed out. (connect timeout=10)'))

# %%
metadata = hitted_metadatas[0]
#print(json.dumps(metadata, indent=2))

# %%
new_df = Utils.get_dataset(metadata=metadata["_source"], variables=[0,1, 2, 3], constrains={
            "date_range": {
                "start": "2018-11-23T00:00:00",
                "end": "2018-12-06T00:00:00"
            }
        })
new_df

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-83-9fe87a9ce070> in <module>
#       2             "date_range": {
#       3                 "start": "2018-11-23T00:00:00",
# ----> 4                 "end": "2018-12-06T00:00:00"
#       5             }
#       6         })
#
# ~/PycharmProjects/datamart/example/../datamart/utilities/utils.py in get_dataset(cls, metadata, variables, constrains)
#     295
#     296         if variables:
# --> 297             df = df.iloc[:, variables]
#     298
#     299         if metadata.get("implicit_variables", None):
#
# ~/anaconda3/envs/datamart_env/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1365             except (KeyError, IndexError):
#    1366                 pass
# -> 1367             return self._getitem_tuple(key)
#    1368         else:
#    1369             # we by definition only have the 0th axis
#
# ~/anaconda3/envs/datamart_env/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1735     def _getitem_tuple(self, tup):
#    1736
# -> 1737         self._has_valid_tuple(tup)
#    1738         try:
#    1739             return self._getitem_lowerdim(tup)
#
# ~/anaconda3/envs/datamart_env/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     202             if i >= self.obj.ndim:
#     203                 raise IndexingError('Too many indexers')
# --> 204             if not self._has_valid_type(k, i):
#     205                 raise ValueError("Location based indexing can only have "
#     206                                  "[{types}] types"
#
# ~/anaconda3/envs/datamart_env/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1672             return self._is_valid_integer(key, axis)
#    1673         elif is_list_like_indexer(key):
# -> 1674             return self._is_valid_list_like(key, axis)
#    1675         return False
#    1676
#
# ~/anaconda3/envs/datamart_env/lib/python3.6/site-packages/pandas/core/indexing.py in _is_valid_list_like(self, key, axis)
#    1729         if (hasattr(arr, '__len__') and len(arr) and
#    1730                 (arr.max() >= l or arr.min() < -l)):
# -> 1731             raise IndexError("positional indexers are out-of-bounds")
#    1732
#    1733         return True
#
# IndexError: positional indexers are out-of-bounds

# %% [markdown]
# ### Querying FTSE 100

# %%
# hitted_metadatas = augment.query(
#     query_string="FTSE 100 United Kingdom"
# )
hitted_metadatas = augment.query(
    global_datamart_id=118390000
)
#118390000
print(len(hitted_metadatas))
# Out:
# 1

# %%
metadata = hitted_metadatas[0]
#print(json.dumps(metadata, indent=2))

# %%
new_df = Utils.get_dataset(metadata=metadata["_source"], variables=[0,1, 2, 3], constrains={
            "date_range": {
                "start": "2018-11-23T00:00:00",
                "end": "2018-12-06T00:00:00"
            }
        })
new_df
# Out:
#     Symbol        Date     Open     High
# 0  UKX:IND  06/12/2018  6921.84  6921.84
# 1  UKX:IND  05/12/2018  7022.76  7028.65
# 2  UKX:IND  04/12/2018  7062.41  7095.01
# 3  UKX:IND  03/12/2018  6980.24  7145.49
# 4  UKX:IND  30/11/2018  7038.95  7042.07
# 5  UKX:IND  29/11/2018  7004.52  7078.37
# 6  UKX:IND  28/11/2018  7016.85  7057.03
# 7  UKX:IND  27/11/2018  7036.00  7043.70
# 8  UKX:IND  26/11/2018  6952.86  7050.96
# 9  UKX:IND  23/11/2018  6960.32  6987.53

# %% [markdown]
# ### Querying GDP Annual Growth

# %%
hitted_metadatas = augment.query(
    query_string="GDP Annual Growth Rate"
)

print(len(hitted_metadatas))
# Out:
# 1819

# %%
metadata = hitted_metadatas[0]
# for metadata in enumerate(hitted_metadatas:
#     print(json.dumps(metadata, indent=2))

# %%
old_df = pd.DataFrame(data={
    'country': ["Finland","Germany"],
})

# %%
new_df = Utils.get_dataset(metadata=metadata["_source"], variables=[0,1, 2, 3], constrains={
            "named_entity": {
                0: old_df.loc[:, 'country'].unique().tolist()
            },
            "date_range": {
                "start": "2017-05-23T00:00:00",
                "end": "2018-12-06T00:00:00"
            }
        })
new_df
# Out:
#     Country                Category                DateTime  Close
# 0   Finland  GDP Annual Growth Rate   6/30/2017 12:00:00 AM    3.2
# 1   Germany  GDP Annual Growth Rate   6/30/2017 12:00:00 AM    2.2
# 2   Finland  GDP Annual Growth Rate   9/30/2017 12:00:00 AM    2.2
# 3   Germany  GDP Annual Growth Rate   9/30/2017 12:00:00 AM    2.6
# 4   Finland  GDP Annual Growth Rate  12/31/2017 12:00:00 AM    2.6
# 5   Germany  GDP Annual Growth Rate  12/31/2017 12:00:00 AM    2.8
# 6   Finland  GDP Annual Growth Rate   3/31/2018 12:00:00 AM    2.6
# 7   Germany  GDP Annual Growth Rate   3/31/2018 12:00:00 AM    2.1
# 8   Finland  GDP Annual Growth Rate   6/30/2018 12:00:00 AM    2.3
# 9   Germany  GDP Annual Growth Rate   6/30/2018 12:00:00 AM    2.0
# 10  Finland  GDP Annual Growth Rate   9/30/2018 12:00:00 AM    2.4
# 11  Germany  GDP Annual Growth Rate   9/30/2018 12:00:00 AM    1.1
