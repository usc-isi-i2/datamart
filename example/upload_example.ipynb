# %%
import sys
sys.path.append('/Users/dongyuli/isi/repos/datamart')
from datamart import upload
import json
with open('/Users/dongyuli/datamart/contribute2.json') as f:
    description = json.load(f)
res = upload(description)
print(json.dumps(res, indent=2))
# Out:
# ==== Creating metadata and indexing for dict
# {
#   "datamart_id": 290300000,
#   "title": "Company information",
#   "description": "list the country and contact person of each company",
#   "materialization": {
#     "python_path": "general_materializer",
#     "arguments": {
#       "url": "https://www.w3schools.com/html/html_tables.asp",
#       "file_type": "html"
#     }
#   },
#   "variables": [
#     {
#       "datamart_id": 290300001,
#       "semantic_type": [],
#       "name": "Company",
#       "description": "column name: Company, dtype: object",
#       "named_entity": [
#         "Alfreds Futterkiste",
#         "Centro comercial Moctezuma",
#         "Ernst Handel",
#         "Island Trading",
#         "Laughing Bacchus Winecellars",
#         "Magazzini Alimentari Riuniti"
#       ]
#     },
#     {
#       "datamart_id": 290300002,
#       "semantic_type": [],
#       "name": "Contact",
#       "description": "column name: Contact, dtype: object",
# ...

# %%
from datamart.utilities.utils import Utils
data = Utils.get_dataset(res)
print(data)
# Out:
#                         Company           Contact  Country
# 0           Alfreds Futterkiste      Maria Anders  Germany
# 1    Centro comercial Moctezuma   Francisco Chang   Mexico
# 2                  Ernst Handel     Roland Mendel  Austria
# 3                Island Trading     Helen Bennett       UK
# 4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
# 5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy

# %%
wikidata = Utils.get_dataset({
    "materialization": {
            "python_path": "wikidata_spo_materializer",
            "arguments": {
              "property": "P355"
            }
          }
})
print(wikidata)
# Out:
#                                          source  \
# 0      http://www.wikidata.org/entity/Q11670423
# 1          http://www.wikidata.org/entity/Q2283
# 2        http://www.wikidata.org/entity/Q180855
# 3        http://www.wikidata.org/entity/Q126399
# 4       http://www.wikidata.org/entity/Q1475272
# 5        http://www.wikidata.org/entity/Q170027
# 6      http://www.wikidata.org/entity/Q11947725
# 7        http://www.wikidata.org/entity/Q504998
# 8       http://www.wikidata.org/entity/Q4294809
# 9        http://www.wikidata.org/entity/Q158205
# 10       http://www.wikidata.org/entity/Q136778
# 11     http://www.wikidata.org/entity/Q15238661
# 12        http://www.wikidata.org/entity/Q34433
# 13      http://www.wikidata.org/entity/Q1636974
# 14       http://www.wikidata.org/entity/Q163241
# 15      http://www.wikidata.org/entity/Q1472929
# 16       http://www.wikidata.org/entity/Q137910
# 17      http://www.wikidata.org/entity/Q1164193
# ...
